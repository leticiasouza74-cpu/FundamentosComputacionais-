# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiasouza74-cpu/FundamentosComputacionais-/blob/main/FC_16_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Funções básica

# %%
def soma(a,b):
  """
  Esta função executa a soma de dois números a e b
  """
  return a + b

def sub(a,b):
  return a - b
