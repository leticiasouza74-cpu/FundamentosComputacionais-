# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiasouza74-cpu/FundamentosComputacionais-/blob/main/FC_16_04_aplicando_fun%C3%A7%C3%A3o_b%C3%A1sica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/leticiasouza74-cpu/FundamentosComputacionais-.git
# Out:
# Cloning into 'FundamentosComputacionais-'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 20 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 4.36 KiB | 2.18 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
ls
# Out:
# FundamentosComputacionais-/  sample_data/

# %%
#executar o notebook com as funções
# %run FundamentosComputacionais-/FC_16_04.ipynb

# %%
#Verificando as funções importadas
if callable(soma) and callable(sub):
  print('Funções importadas com sucesso!')
else:
  print('Erro ao importar as funções')
# Out:
# Funções importadas com sucesso!

# %%
print(soma.__doc__)
# Out:
#    Esta função executa a soma de dois números a e b

# %%
soma(2,8)
# Out:
# 10

# %%
sub(6,9)
# Out:
# -3
